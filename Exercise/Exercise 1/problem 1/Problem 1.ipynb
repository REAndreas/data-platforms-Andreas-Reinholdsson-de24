# %%
import pandas as pd

df_grades = pd.read_excel("Data/betyg_o_prov_riksnivå.xlsx", sheet_name="Tabell 1B", skiprows=7)

df_grades
# Out:
#                                            Unnamed: 0  Totalt  Flickor  \
# 0                                             2018/19   221.7    234.3
# 1                                             2019/20   222.9    235.7
# 2                                             2020/21   223.9    235.4
# 3                                             2021/22   221.2    231.6
# 4                                             2022/23   220.6    229.7
# 5                                               därav     NaN      NaN
# 6                                              Kommun   216.1    225.6
# 7                                             Enskild   237.9    245.0
# 8                                               därav     NaN      NaN
# 9                                   Allmän inriktning   238.5    245.8
# 10                                      Konfessionell   225.6    230.5
# 11                                            Waldorf   236.3    239.0
# ...

# %%
import matplotlib.pyplot as plt
 
year_18_19 = df_grades.query("`Unnamed: 0` == '2018/19'")["Totalt.2"]
year_19_20 = df_grades.query("`Unnamed: 0` == '2019/20'")["Totalt.2"]
year_20_21 = df_grades.query("`Unnamed: 0` == '2020/21'")["Totalt.2"]
year_21_22 = df_grades.query("`Unnamed: 0` == '2021/22'")["Totalt.2"]
year_22_23 = df_grades.query("`Unnamed: 0` == '2022/23'")["Totalt.2"]
 
data_dict = {
    "2018/19": year_18_19,
    "2019/20": year_19_20,
    "2020/21": year_20_21,
    "2021/22": year_21_22,
    "2022/23": year_22_23,
}
plt.plot(data_dict.keys(), data_dict.values(),'--o')
